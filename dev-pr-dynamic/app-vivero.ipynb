# %% [markdown]
# ##  Problema: Crecimiento de Producción en un Vivero
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
# @title Ingrese datos
nombre_estudiante = "Leonardo Gonzalez Oliveros" 
carnet = 1000116657

# %% [markdown]
# ## 1) Descripción del problema **[1 pts]**
#
#
# Un vivero está analizando el crecimiento de la producción de nuevas plantas a partir de un proceso de reproducción controlada.
# Se ha observado que el número de nuevas plantas producidas en el mes n sigue el siguiente comportamiento:
#
# • En el mes 0 se produjeron 0 nuevas plantas.
#
# • En el mes 1 se produjo 1 nueva planta.
#
# • A partir del mes 2, el número de nuevas plantas producidas es igual a la suma de las plantas producidas durante los dos meses anteriores, debido a que las plantas que alcanzan su etapa de reproducción generan nuevos brotes siguiendo este patrón de crecimiento.
#
# La funcion de recurrencia desde el mes 2 es:
#
# T(n) = T(n-1) + T(n-2) si n ≥ 2

# %% [markdown]
# ## 2) Requerimientos **[2 pts]**
#
# RQF1: El sistema debe permitir ingresar una cantidad m de meses.
#
# RQF2: El sistema debe calcular la cantidad de plantas en el mes m en base a la cantidad de los meses anteriores.
#
# RQF3: El sistema debe mostrar al usuario la cantidad de plantas para el mes indicado.
#
#
# RQNF1: (Eficiencia) El sistema hace uso de la memoizacion para guardar la cantidad de plantas de meses anteriores para usarlas despues.
#
# RQNF2: (Usabilidad)El sistema permite al usuario ingresar un valor correspondiente a los meses, si el dato no es valido genera un mensaje informativo.
#
# RQNF3: (Correcion) El sistema permite ingresar nuevamente el valor si el ingresado anteriormente no es valido.
#
# RQF4: (Mantenibilidad) El sistema esta formado por un unico bulce y memoizacion en un unico arreglo, ademas esta estructurado por una unica funcion diferente del main, lo que permite determinar y encontrar las fallas mas rapido.

# %% [markdown]
# ## 3) Historias de usuario **[2 pts]**
# Como usuario se quiere un espacio para poder ingresar el numero de mes en el cual se quiere visualizar la cantidad de plantas
#
# CA: El valor ingresado debe ser numerico entero positivo, si el valor ingresado no es valido se presenta un mensaje informativo y la opcion de volver a ingresar el valor.
#
#
# Como usuario se quiere que el sistema en base a la cantidad de plantas de los ultimos dos meses determine la cantidad del mes ingresado.
#
# CA= El sistema debe usar la cantidad de plantas de los anteriores meses para determinar la cantidad del mes ingresado
#
#
# Como usuario se quiere visualizar la cantidad de plantas en el mes ingresado mediante un mensaje.
#
# Ca=El sistema debe mostrar el mes y la cantidad de plantas en ese tiempo

# %% [markdown]
# ## 4) Diagramas de flujo **[5 pts]**
# ![alt text](<Diagrama en blanco (2)-1.svg>)

# %% [markdown]
# ### 5) Análisis de complejidad **[15 pts]**
# Incluye:
# La complejidad de este algoritmo es de O(n) ya que presenta un unico ciclo while el cual se va a repetir n-1 veces en todo el proceso, Las operaciones realizadas dentro del ciclo tienen una complejidad constante O(1). Por lo tanto, la complejidad total del algoritmo es O(n).
#
# T(n) = T(n-1) + T(n-2) si n ≥ 2
#
#
# El mejor caso se veria representado por f(n)= 1 o 0 ya que es constante no tiene que generar algun recorrido, mientras que entre mas grande sea el valor n, el numero de recorridos y valores guarddos va a ser de n-1.
# - Función T[n]=O(n)
#
# ![alt text](<Diagrama en blanco (1)-1.svg>)

# %% [markdown]
# ## 6) Código funcional **[15 pts]**

# %%
def vivero(n):
    while True:
        try:

            memo=[0,1]
            if n>=2:
                m=2
                while n>=m:
                    plantas=((memo[m-1])+(memo[m-2]))
                    
                    m+=1
                    memo.append(plantas)#Meoizacion
            return n,plantas
                
        except ValueError:
            print("DATO NO VALIDO :(")


def main():
    n=int(input("Ingrese el mes de visualizacion: "))
    n,plantas=vivero(n)
    print(f"En el mes {n} habrian {plantas} plantas")
main()

# %% [markdown]
# ## 7) Tests aplicados **[15 pts]**

# %%
# (Opcional) Ejemplo de asserts (ajusta a tu código):
# |def vivero(2)= |1|
# |def vivero(5)= |5|
# |def vivero(4)= |3|
# |def vivero(10)=|55|
# |def vivero(11)=|89|
